# %% [markdown]
# ## 1. 管理工具安装
# ### 1.1 langchain 安装

# %%
import os

import dotenv
# !pip install langchain

# conda 
# conda install -c conda-forge langchain
# Out:
# Requirement already satisfied: langchain in d:\miniconda3\lib\site-packages (1.2.12)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\miniconda3\lib\site-packages (from langchain) (1.2.19)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in d:\miniconda3\lib\site-packages (from langchain) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\miniconda3\lib\site-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.20)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\miniconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\miniconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\miniconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in d:\miniconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\miniconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\miniconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\miniconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.24.0)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)

# %% [markdown]
# ### 1.2 其他库安装

# %%
# 直接转换为 REST API
# !pip install "langserve[all]"

# 观测平台
# !pip install -U langsmith

# LangGraph
# !pip install -U langgraph

# DeepSeek
# !pip install langchain-deepseek

# 外部资源集成
# !pip install langchain_community

# dotenv管理密钥，加载环境变量等
# !pip install python-dotenv

# !pip install langchain-classic
# Out:
# Requirement already satisfied: langserve[all] in d:\miniconda3\lib\site-packages (0.3.3)
# Requirement already satisfied: fastapi<1,>=0.90.1 in d:\miniconda3\lib\site-packages (from langserve[all]) (0.135.1)
# Requirement already satisfied: httpx<1.0,>=0.23.0 in d:\miniconda3\lib\site-packages (from langserve[all]) (0.28.1)
# Requirement already satisfied: langchain-core<2,>=0.3 in d:\miniconda3\lib\site-packages (from langserve[all]) (1.2.19)
# Requirement already satisfied: orjson<4,>=2 in d:\miniconda3\lib\site-packages (from langserve[all]) (3.11.7)
# Requirement already satisfied: pydantic<3.0,>=2.7 in d:\miniconda3\lib\site-packages (from langserve[all]) (2.12.3)
# Requirement already satisfied: sse-starlette<2.0.0,>=1.3.0 in d:\miniconda3\lib\site-packages (from langserve[all]) (1.8.2)
# Requirement already satisfied: starlette>=0.46.0 in d:\miniconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (0.52.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\miniconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\miniconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (0.0.4)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.23.0->langserve[all]) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\miniconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\miniconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-core<2,>=0.3->langserve[all]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\miniconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\miniconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=0.3->langserve[all]) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic<3.0,>=2.7->langserve[all]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic<3.0,>=2.7->langserve[all]) (2.41.4)
# Requirement already satisfied: uvicorn in d:\miniconda3\lib\site-packages (from sse-starlette<2.0.0,>=1.3.0->langserve[all]) (0.42.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (2.5.0)
# Requirement already satisfied: click>=7.0 in d:\miniconda3\lib\site-packages (from uvicorn->sse-starlette<2.0.0,>=1.3.0->langserve[all]) (8.1.8)
# Requirement already satisfied: colorama in d:\miniconda3\lib\site-packages (from click>=7.0->uvicorn->sse-starlette<2.0.0,>=1.3.0->langserve[all]) (0.4.6)
# Requirement already satisfied: langsmith in d:\miniconda3\lib\site-packages (0.7.22)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\miniconda3\lib\site-packages (from langsmith) (3.11.7)
# Requirement already satisfied: packaging>=23.2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langsmith) (25.0)
# Requirement already satisfied: pydantic<3,>=2 in d:\miniconda3\lib\site-packages (from langsmith) (2.12.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langsmith) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langsmith) (0.14.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\miniconda3\lib\site-packages (from langsmith) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith) (0.24.0)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic<3,>=2->langsmith) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic<3,>=2->langsmith) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in d:\miniconda3\lib\site-packages (from pydantic<3,>=2->langsmith) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from pydantic<3,>=2->langsmith) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith) (2.5.0)
# Requirement already satisfied: langgraph in d:\miniconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: langchain-core>=0.1 in d:\miniconda3\lib\site-packages (from langgraph) (1.2.19)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\miniconda3\lib\site-packages (from langgraph) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\miniconda3\lib\site-packages (from langgraph) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\miniconda3\lib\site-packages (from langgraph) (0.3.11)
# Requirement already satisfied: pydantic>=2.7.4 in d:\miniconda3\lib\site-packages (from langgraph) (2.12.3)
# Requirement already satisfied: xxhash>=3.5.0 in d:\miniconda3\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\miniconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\miniconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\miniconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\miniconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\miniconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\miniconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\miniconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\miniconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: langchain-deepseek in d:\miniconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\miniconda3\lib\site-packages (from langchain-deepseek) (1.2.19)
# Requirement already satisfied: langchain-openai<2.0.0,>=1.0.0 in d:\miniconda3\lib\site-packages (from langchain-deepseek) (1.1.11)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.0.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in d:\miniconda3\lib\site-packages (from langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (2.29.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\miniconda3\lib\site-packages (from langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.24.0)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\miniconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\miniconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (0.13.0)
# Requirement already satisfied: sniffio in d:\miniconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\miniconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in d:\miniconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (2026.2.28)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.5.0)
# Requirement already satisfied: colorama in d:\miniconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (0.4.6)
# Requirement already satisfied: langchain_community in d:\miniconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in d:\miniconda3\lib\site-packages (from langchain_community) (1.2.19)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\miniconda3\lib\site-packages (from langchain_community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\miniconda3\lib\site-packages (from langchain_community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in d:\miniconda3\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\miniconda3\lib\site-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\miniconda3\lib\site-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\miniconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\miniconda3\lib\site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in d:\miniconda3\lib\site-packages (from langchain_community) (0.7.22)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\miniconda3\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in d:\miniconda3\lib\site-packages (from langchain_community) (2.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\miniconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\miniconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\miniconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in d:\miniconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\miniconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.24.0)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\miniconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in d:\miniconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\miniconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: python-dotenv in d:\miniconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-classic in d:\miniconda3\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.19 in d:\miniconda3\lib\site-packages (from langchain-classic) (1.2.19)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in d:\miniconda3\lib\site-packages (from langchain-classic) (1.1.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in d:\miniconda3\lib\site-packages (from langchain-classic) (0.7.22)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\miniconda3\lib\site-packages (from langchain-classic) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\miniconda3\lib\site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in d:\miniconda3\lib\site-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.19->langchain-classic) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.24.0)
# Requirement already satisfied: anyio in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.12.1)
# Requirement already satisfied: certifi in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: idna in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuhuijun\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.5.0)
# Requirement already satisfied: greenlet>=1 in d:\miniconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.2)

# %% [markdown]
# ### 1.3 常见的处理链包含三个要素
#
# 1. 语言模型：核心推理引擎
# 2. 提示词模板：提供指令
# 3. 输出解释器：转换为易于使用的格式，便于下游处理

# %% [markdown]
# #### 1.3.1 语言模型
#
# langchain语言模型主要分为两种：
#
# 1. LLM 通用模型：接收字符串作为输入，输出字符串作为输出。
# 2. ChatModel 对话模型：接收消息列表，输出“消息”，用于一问一答。
#
# 消息：由 BaseMessage 类定义，包含文本、时间戳、用户标识符等属性。主要的有
#
# 1. 消息的内容：文本，通常是字符串
# 2. 角色：消息的发送方
#
# 角色： LangChain 用于区分不同角色的对象
#
# 1. HumanMessage：人类（用户）输入的BaseMessage。
# 2. AIMessage：AI助手（大模型）输出的BaseMessage。
# 3. SystemMessage：系统预设的BaseMessage。
# 4. FunctionMessage：自定义函数输出的BaseMessage。
# 5. ToolMessage：调用第三方工具输出的BaseMessage。
# 6. ChatMessage：自定义角色。
#
# 方法： LCEL 默认实现同步调用方法，最常见的是 invoke 方法，接受一个 BaseMessage 对象作为参数，并返回一个 BaseMessage 对象作为结果。
#
# 比如：
# LLMs.invoke：输入输出都是字符串
# ChatModels.invoke：输入输出都是BaseMessage对象

# %%
from langchain_community.llms.tongyi import  Tongyi
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("DASHSCOPE_API_KEY")
llm = Tongyi()

print(llm.invoke("你好"))
print(llm.invoke("你好，今天天气怎么样？"))
# Out:
# 你好！很高兴见到你～😊 有什么我可以帮你的吗？无论是学习、工作、生活中的问题，还是想聊聊天、获取信息、一起动脑筋，我都很乐意帮忙！
# 你好！😊 我目前无法实时获取你所在地的天气信息（因为没有访问设备定位或网络的权限），但你可以通过以下方式快速查看：
#
# 🔹 打开手机自带的天气App（如“天气”、“墨迹天气”等）
# 🔹 在微信/支付宝中搜索“天气”，使用城市定位查询
# 🔹 或直接在浏览器搜索“XX市（你的城市）今日天气”
#
# 如果你告诉我你所在的城市，我也可以帮你分析当前季节的典型天气特征、穿衣建议，或者提供一些实用的天气小贴士哦～ 🌤️☔🧥
# 需要的话随时告诉我～ 😊

# %%
from langchain_deepseek import ChatDeepSeek
load_dotenv()
deepseek = ChatDeepSeek(model="deepseek-chat")

print(deepseek.invoke("你好"))
# Out:
# content='你好！很高兴见到你！😊 我是DeepSeek，由深度求索公司创造的AI助手。无论你有什么问题、需要什么帮助，或者只是想聊聊天，我都很乐意为你提供支持！\n\n我可以帮你解答各种问题，比如学习、工作、生活方面的疑惑，也可以协助你进行文本处理、分析、创作等等。有什么我可以为你做的吗？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 76, 'prompt_tokens': 5, 'total_tokens': 81, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 5}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': '301f1bef-6378-4f61-85f0-710d287f75aa', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d1b64-75d0-7b33-8493-ea93368cd84c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 76, 'total_tokens': 81, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}

# %% [markdown]
# #### 1.3.2 提示词模板
#
# 提示词模板是用于生成提示词的模板。例如，`{name}，你好！我是你的朋友小爱同学。`就是一个提示词模板。
#
# 提示词模板中可以使用变量，变量名由字母、数字和下划线组成，且必须以字母开头。例如，`{name}，你好！我是你的朋友小爱同学。`中的`{name}`就是一个变量。

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    "Hello, I am a {model_name}. How can I help you today?"
)
prompt.format(model_name="chatbot")
# Out:
# 'Hello, I am a chatbot. How can I help you today?'

# %%
# 使用 ChatPromptTemplate 创建对话模板
from langchain_core.prompts import ChatPromptTemplate

# 创建包含 system 和 human 消息的聊天模板
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant named {assistant_name}."),
    ("human", "Hello, my name is {user_name}. {question}")
])

# 格式化消息
messages = chat_prompt.format_messages(
    assistant_name="Claude",
    user_name="Alice", 
    question="What's the weather like today?"
)

for message in messages:
    print(f"{message.type}: {message.content}")
# Out:
# system: You are a helpful AI assistant named Claude.
# human: Hello, my name is Alice. What's the weather like today?

# %%
from langchain_core.prompts import PromptTemplate

# 多变量模板
complex_prompt = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="""
    请为{audience}写一篇关于{topic}的文章。
    写作风格应该是{tone}的。
    
    文章要求：
    - 内容准确且有用
    - 结构清晰
    - 适合目标受众
    """
)

formatted_prompt = complex_prompt.format(
    topic="人工智能",
    audience="初学者",
    tone="通俗易懂"
)
print(formatted_prompt)
# Out:
#     请为初学者写一篇关于人工智能的文章。
#     写作风格应该是通俗易懂的。
#
#     文章要求：
#     - 内容准确且有用
#     - 结构清晰
#     - 适合目标受众

# %%
from langchain_core.prompts import PromptTemplate

# f-string 风格、jinja2语法 ...
f_string_prompt = PromptTemplate.from_template(
    "分析以下{data_type}数据：\n{data}\n\n请提供{analysis_type}分析。"
)

result = f_string_prompt.format(
    data_type="销售",
    data="Q1销售额: 100万, Q2销售额: 120万",
    analysis_type="趋势"
)
print(result)
# Out:
# 分析以下销售数据：
# Q1销售额: 100万, Q2销售额: 120万
#
# 请提供趋势分析。

# %%
from langchain_core.prompts import PromptTemplate

# 带条件逻辑的模板
conditional_prompt = PromptTemplate(
    input_variables=["user_type", "question"],
    template="""
    {%- if user_type == "expert" -%}
    作为专家，请详细回答：{question}
    {%- else -%}
    请用简单易懂的方式回答：{question}
    {%- endif -%}
    """
)

# %% [markdown]
# #### 1.3.3 输出解析器
#
# 输出解析器是 LangChain 中的重要组件，用于将大语言模型(LLM)的原始文本输出转换为结构化数据格式，便于程序进一步处理和使用。
#
# 主要功能
# - 格式化输出: 将 LLM 的自然语言输出解析为 JSON、XML、列表等结构化格式
# - 类型转换: 将文本数据转换为 Python 对象（字典、列表、自定义类等）
# - 数据验证: 确保输出符合预期的格式和约束条件
# - 错误处理: 处理解析失败的情况，提供重试机制
#
# 常见的输出解析器类型

# %%
# JSON 输出解析器
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

class PersonInfo(BaseModel):
    name: str = Field(description="人物姓名")
    age: int = Field(description="年龄")
    occupation: str = Field(description="职业")

parser = PydanticOutputParser(pydantic_object=PersonInfo)

# 列表输出解析器

from langchain_core.output_parsers import CommaSeparatedListOutputParser

parser = CommaSeparatedListOutputParser()
# 将 "苹果,香蕉,橙子" 解析为 ["苹果", "香蕉", "橙子"]

# 结构化输出解析器
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema

response_schemas = [
    ResponseSchema(name="answer", description="问题的答案"),
    ResponseSchema(name="source", description="答案来源")
]
parser = StructuredOutputParser.from_response_schemas(response_schemas)

# %%
# 手动使用解析器
parser = CommaSeparatedListOutputParser()

# 模拟 LLM 的原始输出
raw_output = "Python, Java, JavaScript, C++, Go"

# 解析输出
parsed_result = parser.parse(raw_output)
print("手动解析结果:", parsed_result)
# 输出: ['Python', 'Java', 'JavaScript', 'C++', 'Go']
# Out:
# 手动解析结果: ['Python', 'Java', 'JavaScript', 'C++', 'Go']

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_community.llms import Tongyi

# 初始化
parser = CommaSeparatedListOutputParser()
llm = Tongyi(temperature=0)

# 直接构建提示并调用
def simple_list_generation(category):
    # 手动构建提示
    prompt = f"""请列出5个{category}的例子。
{parser.get_format_instructions()}"""
    
    # 直接调用LLM
    response = llm.invoke(prompt)
    
    # 解析结果
    return parser.parse(response)


# 使用
fruits = simple_list_generation("水果")
print("水果列表:", fruits)

languages = simple_list_generation("编程语言")
print("编程语言列表:", languages)
# Out:
# 水果列表: ['apple', 'banana', 'orange', 'grape', 'strawberry']
# 编程语言列表: ['Python', 'JavaScript', 'Java', 'C++', 'Ruby']

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.llms.tongyi import Tongyi

# 1. 创建输出解析器
parser = CommaSeparatedListOutputParser()

# 2. 获取格式化指令
format_instructions = parser.get_format_instructions()
print("格式化指令:", format_instructions)

# 3. 创建包含格式指令的提示模板
prompt = PromptTemplate(
    template="请列出5个{category}的例子。\n{format_instructions}",
    input_variables=["category"],
    partial_variables={"format_instructions": format_instructions}
)

# 4. 初始化 LLM
llm = Tongyi(temperature=0)

# 5. 创建完整的链
chain = prompt | llm | parser

# 6. 使用示例
try:
    # 调用链并获取解析后的结果
    result = chain.invoke({"category": "水果"})
    print("解析后的结果:", result)
    print("结果类型:", type(result))
    # 输出示例: ['苹果', '香蕉', '橙子', '葡萄', '草莓']
    
    # 遍历结果
    for i, fruit in enumerate(result, 1):
        print(f"{i}. {fruit}")
        
except Exception as e:
    print(f"解析错误: {e}")

# 7. 更复杂的示例 - 多个类别
categories = ["编程语言", "运动项目", "乐器"]

for category in categories:
    print(f"\n=== {category} ===")
    try:
        result = chain.invoke({"category": category})
        for item in result:
            print(f"• {item}")
    except Exception as e:
        print(f"处理 {category} 时出错: {e}")
# Out:
# 格式化指令: Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
# 解析后的结果: ['apple', 'banana', 'orange', 'grape', 'strawberry']
# 结果类型: <class 'list'>
# 1. apple
# 2. banana
# 3. orange
# 4. grape
# 5. strawberry
#
# === 编程语言 ===
# • Python
# • JavaScript
# • Java
# • C++
# • Ruby
#
# === 运动项目 ===
# • Running
# • Swimming
# • Cycling
# • Basketball
# • Tennis
#
# === 乐器 ===
# • piano
# • guitar
# • violin
# • flute
# • drums

# %%
# 购物清单
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import Tongyi

# 1. 初始化组件
parser = CommaSeparatedListOutputParser()
llm = Tongyi(temperature=0)

# 2. 创建提示模板
shopping_prompt = PromptTemplate(
    template="根据{meal_type}，生成一个包含5个食材的购物清单。\n{format_instructions}",
    input_variables=["meal_type"],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)

# 3. 创建链
shopping_chain = shopping_prompt | llm | parser

# 4. 生成不同餐型的购物清单
meals = ["早餐", "午餐", "晚餐"]
shopping_lists = {}

for meal in meals:
    shopping_lists[meal] = shopping_chain.invoke({"meal_type": meal})
    print(f"{meal}购物清单: {shopping_lists[meal]}")

# 5. 格式化输出
print("\n=== 详细购物清单 ===")
for meal, items in shopping_lists.items():
    print(f"\n🍽️ {meal}:")
    for i, item in enumerate(items, 1):
        print(f"  {i}. {item}")
# Out:
# 早餐购物清单: ['eggs', 'whole grain bread', 'bananas', 'Greek yogurt', 'oatmeal']
# 午餐购物清单: ['chicken breast', 'brown rice', 'broccoli', 'cherry tomatoes', 'olive oil']
# 晚餐购物清单: ['chicken breast', 'broccoli', 'brown rice', 'garlic', 'olive oil']
#
# === 详细购物清单 ===
#
# 🍽️ 早餐:
#   1. eggs
#   2. whole grain bread
#   3. bananas
#   4. Greek yogurt
#   5. oatmeal
#
# 🍽️ 午餐:
#   1. chicken breast
#   2. brown rice
#   3. broccoli
#   4. cherry tomatoes
#   5. olive oil
#
# 🍽️ 晚餐:
#   1. chicken breast
#   2. broccoli
#   3. brown rice
#   4. garlic
#   5. olive oil

# %%
# 多场景
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import Tongyi

# 通用列表生成链
parser = CommaSeparatedListOutputParser()
list_chain = (
    PromptTemplate(
        template="请列出5个{category}的{item_type}。\n{format_instructions}",
        input_variables=["category", "item_type"],
        partial_variables={"format_instructions": parser.get_format_instructions()}
    )
    | Tongyi(temperature=0)
    | parser
)

# 多场景使用
scenarios = [
    {"category": "早餐", "item_type": "食材"},
    {"category": "办公室", "item_type": "用品"},
    {"category": "旅行", "item_type": "必需品"},
    {"category": "健身", "item_type": "器材"},
    {"category": "学习", "item_type": "工具"}
]

for scenario in scenarios:
    result = list_chain.invoke(scenario)
    print(f"{scenario['category']}{scenario['item_type']}: {result}")
# Out:
# 早餐食材: ['oats', 'eggs', 'bananas', 'yogurt', 'whole wheat bread']
# 办公室用品: ['pen', 'notebook', 'stapler', 'paperclip', 'printer']
# 旅行必需品: ['Passport', 'travel insurance', 'smartphone', 'charger', 'comfortable walking shoes']
# 健身器材: ['dumbbells', 'barbell', 'treadmill', 'resistance bands', 'pull-up bar']
# 学习工具: ['Anki', 'Notion', 'Khan Academy', 'Coursera', 'Quizlet']

# %% [markdown]
# #### 1.3.4 使用 LCEL 的好处
#
# 1. 简洁语法: 使用管道操作符 | 创建链，代码直观易读
# 2. 自动类型推断: 组件间数据类型自动转换，减少手动处理
# 3. 并行处理: 内置并行执行能力，提高处理效率
# 4. 流式处理: 原生支持流式输出，适合实时应用
# 5. 智能缓存: 自动缓存中间结果，避免重复计算
# 6. 内置调试: 更好的调试和监控能力
# 7. 插件化: 支持自定义组件和扩展
# 8. 标准接口: 统一的 Runnable 接口
# 9. 版本管理: 支持链的版本控制和管理
